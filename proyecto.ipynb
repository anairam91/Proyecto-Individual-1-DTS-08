# %% [markdown]
# comenzaremos importando las librerias necesarias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# realizamos la ingesta de archivos

# %%
amazon= pd.read_csv ('Datasets/amazon_prime_titles.csv')
disneyplus = pd.read_csv ('Datasets/disney_plus_titles.csv')
hulu = pd.read_csv ('Datasets/hulu_titles.csv')
netflix = pd.read_csv ('Datasets/netflix_titles.csv')

# %% [markdown]
# comenzamos con el proceso de EDA(Explory Data Analysis)

# %%
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
disneyplus. head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# ...

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Buscamos lo valores nulos y los sumamos

# %%
amazon.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
disneyplus.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
hulu.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# dtype: int64

# %%
netflix.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# vemos la cantidad de filas y columnas de cada uno

# %%
amazon.shape
# Out:
# (9668, 12)

# %%
disneyplus.shape
# Out:
# (1450, 12)

# %%
hulu.shape
# Out:
# (3073, 12)

# %%
netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# se identifican los datos duplicados y en caso de existir se eliminan

# %%
amazon[amazon.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
disneyplus[disneyplus.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
hulu[hulu.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
netflix[netflix.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# como nos  podemos dar cuenta ningun archivo tiene datos duplicados

# %% [markdown]
# separamos minutos y por otro lado la cantidad de temporadas

# %%
amazon['min']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split()[1]=='min' 
    else '0')

amazon['seasons']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split(" ",1)[1]=='Seasons' or i.split(" ",1)[1]=='Season' 
    else '0')

# %%
amazon.head(5)
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
disneyplus['min']= disneyplus['duration'].apply(lambda i: i.split()[0] 
    if i.split()[1]=='min' 
    else '0')

disneyplus['seasons']= disneyplus['duration'].apply(lambda i: i.split()[0] 
    if i.split(" ",1)[1]=='Seasons' or i.split(" ",1)[1]=='Season' 
    else '0')

# %%
disneyplus.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
hulu['min']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split()[1]=='min' 
    else '0')

hulu['seasons']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split(" ",1)[1]=='Seasons' or i.split(" ",1)[1]=='Season' 
    else '0')

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description  min seasons
# ...

# %%
netflix['min']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split()[1]=='min' 
    else '0')

netflix['seasons']= amazon['duration'].apply(lambda i: i.split()[0] 
    if i.split(" ",1)[1]=='Seasons' or i.split(" ",1)[1]=='Season' 
    else '0')

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#amazon
#creaar ID
amazon['ID']= ['a'] + amazon['show_id']
#remplazar los valores los nulos en raiting por G:
amazon['rating'] = amazon ['rating'].replace(np.nan, 'g')
#formato de fechas 
amazon['date_added'] = pd.to_datetime(amazon['date_added'], format= '%B %d, %Y')
#Modificar los campos de texto para que esten en minusculas
amazon['type'] = amazon['type'].str.lower()
amazon['title'] = amazon['title'].str.lower()
amazon['director'] = amazon['director'].str.lower()
amazon['cast'] = amazon['cast'].str.lower()
amazon['country'] = amazon['country'].str.lower()
amazon['rating'] = amazon['rating'].str.lower()
amazon['duration'] = amazon['duration'].str.lower()
amazon['listed_in'] = amazon['listed_in'].str.lower()
amazon['description'] = amazon['description'].str.lower()

# %%
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      the grand seduction     don mckellar
# 1         s2    movie     take care good night     girish joshi
# 2         s3    movie     secrets of deception      josh webber
# 3         s4    movie       pink: staying true   sonia anderson
# 4         s5    movie            monster maker     giles foster
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      pride of the bowery  joseph h. lewis
# 9664   s9665  tv show            planet patrol              NaN
# 9665   s9666    movie                  outpost     steve barker
# 9666   s9667  tv show  maradona: blessed dream              NaN
# 9667   s9668    movie              harry brown    daniel barber
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# ...

# %%
#disneyplus
#creaar ID
disneyplus['ID']= ['a'] + disneyplus['show_id']
#remplazar los valores los nulos en raiting por G:
disneyplus['rating'] = disneyplus ['rating'].replace(np.nan, 'g')
#formato de fechas 
disneyplus['date_added'] = pd.to_datetime(disneyplus['date_added'], format= '%B %d, %Y')
#Modificar los campos de texto para que esten en minusculas
disneyplus['type'] = disneyplus['type'].str.lower()
disneyplus['title'] = disneyplus['title'].str.lower()
disneyplus['director'] = disneyplus['director'].str.lower()
disneyplus['cast'] = disneyplus['cast'].str.lower()
disneyplus['country'] = disneyplus['country'].str.lower()
disneyplus['rating'] = disneyplus['rating'].str.lower()
disneyplus['duration'] = disneyplus['duration'].str.lower()
disneyplus['listed_in'] = disneyplus['listed_in'].str.lower()
disneyplus['description'] = disneyplus['description'].str.lower()

# %%
disneyplus
# Out:
#      show_id     type                                             title  \
# 0         s1    movie  duck the halls: a mickey mouse christmas special
# 1         s2    movie                            ernest saves christmas
# 2         s3    movie                      ice age: a mammoth christmas
# 3         s4    movie                        the queen family singalong
# 4         s5  tv show                             the beatles: get back
# ...      ...      ...                                               ...
# 1445   s1446    movie                          x-men origins: wolverine
# 1446   s1447    movie    night at the museum: battle of the smithsonian
# 1447   s1448    movie                                   eddie the eagle
# 1448   s1449    movie                              bend it like beckham
# 1449   s1450    movie             captain sparky vs. the flying saucers
#
#                                director  \
# 0     alonso ramirez ramos, dave wasson
# ...

# %%
#hulu
#creaar ID
hulu['ID']= ['a'] + hulu['show_id']
#remplazar los valores los nulos en raiting por G:
hulu['rating'] = hulu ['rating'].replace(np.nan, 'g')
#formato de fechas 
hulu['date_added'] = pd.to_datetime(hulu['date_added'], format= '%B %d, %Y')
#Modificar los campos de texto para que esten en minusculas
hulu['type'] = hulu['type'].str.lower()
hulu['title'] = hulu['title'].str.lower()
hulu['director'] = hulu['director'].str.lower()
hulu['country'] = hulu['country'].str.lower()
hulu['rating'] = hulu['rating'].str.lower()
hulu['duration'] = hulu['duration'].str.lower()
hulu['listed_in'] = hulu['listed_in'].str.lower()
hulu['description'] = hulu['description'].str.lower()

# %%
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    movie  ricky velez: here's everything      NaN   NaN
# 1         s2    movie                    silent night      NaN   NaN
# 2         s3    movie                    the marksman      NaN   NaN
# 3         s4    movie                            gaia      NaN   NaN
# 4         s5    movie                        settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  tv show  star trek: the original series      NaN   NaN
# 3069   s3070  tv show              star trek: voyager      NaN   NaN
# 3070   s3071  tv show                       the fades      NaN   NaN
# 3071   s3072  tv show               the twilight zone      NaN   NaN
# 3072   s3073  tv show             tokyo magnitude 8.0      NaN   NaN
#
#              country date_added  release_year rating   duration  \
# 0                NaN 2021-10-24          2021  tv-ma        NaN
# ...

# %%
#netflix
#creaar ID
netflix['ID']= ['a'] + netflix['show_id']
#remplazar los valores los nulos en raiting por G:
netflix['rating'] = netflix ['rating'].replace(np.nan, 'g')
#formato de fechas 
#fechas marcarcan error, necesitamos quitar los espacios innecesarios
netflix['date_added'] =netflix['date_added']. str.strip()
netflix['date_added'] = pd.to_datetime(netflix['date_added'], format= '%B %d, %Y')
#Modificar los campos de texto para que esten en minusculas
netflix['type'] = netflix['type'].str.lower()
netflix['title'] = netflix['title'].str.lower()
netflix['director'] = netflix['director'].str.lower()
netflix['country'] = netflix['country'].str.lower()
netflix['rating'] = netflix['rating'].str.lower()
netflix['duration'] = netflix['duration'].str.lower()
netflix['listed_in'] = netflix['listed_in'].str.lower()
netflix['description'] = netflix['description'].str.lower()

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   dick johnson is dead  kirsten johnson
# 1         s2  tv show          blood & water              NaN
# 2         s3  tv show              ganglands  julien leclercq
# 3         s4  tv show  jailbirds new orleans              NaN
# 4         s5  tv show           kota factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 zodiac    david fincher
# 8803   s8804  tv show            zombie dumb              NaN
# 8804   s8805    movie             zombieland  ruben fleischer
# 8805   s8806    movie                   zoom     peter hewitt
# 8806   s8807    movie                 zubaan      mozez singh
#
#                                                    cast        country  \
# 0                                                   NaN  united states
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   south africa
# ...

# %%
df_conjunto = pd. concat([amazon, disneyplus, hulu, netflix])

# %%
#dividir la columna 'duration' en durationt int y duration_type
df_conjunto[['duration_int', 'duration_type']] = df_conjunto['duration'].str.extract('(\d+)\s*(\w+)')

# %%
#comprobamos que se hayan realizado los cambios 
df_conjunto
# Out:
#      show_id     type                 title         director  \
# 0         s1    movie   the grand seduction     don mckellar
# 1         s2    movie  take care good night     girish joshi
# 2         s3    movie  secrets of deception      josh webber
# 3         s4    movie    pink: staying true   sonia anderson
# 4         s5    movie         monster maker     giles foster
# ...      ...      ...                   ...              ...
# 8802   s8803    movie                zodiac    david fincher
# 8803   s8804  tv show           zombie dumb              NaN
# 8804   s8805    movie            zombieland  ruben fleischer
# 8805   s8806    movie                  zoom     peter hewitt
# 8806   s8807    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# ...

# %%
#transformar el dato de la columna "duration" a entero
df_conjunto['duration_int'] = df_conjunto['duration_int'].astype('Int64')

# %%
#revisamos los cambios
print(df_conjunto['duration_int'].dtype)
# Out:
# Int64

# %%
#revisamos el tipo de datos en las columnas
print(df_conjunto.dtypes)
# Out:
# show_id                  object
# type                     object
# title                    object
# director                 object
# cast                     object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration                 object
# listed_in                object
# description              object
# min                      object
# seasons                  object
# ID                       object
# duration_int              Int64
# duration_type            object
# dtype: object

# %%
#por ultimo exportamos el archivo a un csv nuevo:
df_conjunto.to_csv('pi_completo.csv', index=False)
